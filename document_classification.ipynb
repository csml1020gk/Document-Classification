# %%
#https://github.com/chrismattmann/tika-python

import tika

# %%
from tika import parser

# %%
#test out reading in sample pdf file 
parsed = parser.from_file('sample documents/AMALGAMATION Autopoint Group Inc Amalgamation.pdf')
# Out:
# 2021-07-18 16:06:53,950 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar to C:\Users\qt09n\AppData\Local\Temp\tika-server.jar.
# 2021-07-18 16:07:06,304 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar.md5 to C:\Users\qt09n\AppData\Local\Temp\tika-server.jar.md5.
# 2021-07-18 16:07:06,667 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
print(parsed["metadata"])
# Out:
# {'Content-Type': 'application/pdf', 'Creation-Date': '2020-08-06T16:53:53Z', 'Last-Modified': '2021-04-30T15:00:58Z', 'Last-Save-Date': '2021-04-30T15:00:58Z', 'X-Parsed-By': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.pdf.PDFParser'], 'X-TIKA:content_handler': 'ToTextContentHandler', 'X-TIKA:embedded_depth': '0', 'X-TIKA:parse_time_millis': '2443', 'access_permission:assemble_document': 'true', 'access_permission:can_modify': 'true', 'access_permission:can_print': 'true', 'access_permission:can_print_degraded': 'true', 'access_permission:extract_content': 'true', 'access_permission:extract_for_accessibility': 'true', 'access_permission:fill_in_form': 'true', 'access_permission:modify_annotations': 'true', 'created': '2020-08-06T16:53:53Z', 'date': '2021-04-30T15:00:58Z', 'dc:format': 'application/pdf; version=1.6', 'dcterms:created': '2020-08-06T16:53:53Z', 'dcterms:modified': '2021-04-30T15:00:58Z', 'meta:creation-date': '2020-08-06T16:53:53Z', 'meta:save-date'
# ...

# %%
print(parsed["content"])
# Out:
# !
# -{
# o
# tTto
#
# G)ooo
# o)
# -{
#
#
#
# f*jTtt&'li'$g*iff ,,o#,,,,,ou,u, n s r e r e d e s
# f .ts GovErnment Servrces Services gouvernementauxrontario
# CERTIFICATE CERT!FICAT
# This is lo certily lhat these Ceci ce.lrfie que les presents
# articles are etlective on statuts entrent en vigueur le
#
# .,ANI'AFNT O 1 JANVIEH, 2016
#
# Onta,io Corporalion Number
# Num6ro de la soci6td en Ontario
#
# 1944750
#
# Business Corporations Act / Loi sur les societ6s par actions
#
# Form 4
# Business
# Corporations
# Acf
#
# Formule 4
# Loi sur les
# soci6tds par
# actions
#
# ARTICLES OF AMALGAMATION
# STATUTS DE FUSION
# 1. The name of the amalgamated corporation is: (Set out in BLOCK CApITAL LETTERS)
#
# D6nomination sociale de la soci6t6 issue de la fusion: (Ecrire en LETTRES MAJUSCULES SEULEMENT)
#
# 2. The address of the registered office is:
# Adresse du sidge social :
#
# I495 UPPERJAMES STREET
#
# A U T o P o I N T G R o U P I N C
#
# Slreel
# Rue et
#
# ...
